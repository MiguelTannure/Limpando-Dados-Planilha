# %% [markdown]
# # Monografia Thays
# ### Preciso limpar uma base de dados proveniente de uma pesquisa feita para argumentar ponto de vista em uma Trabalho de Conclusão do Curso afim de que possam ser feitas análises estatísticas.
#
# 1- Primeiro vamos importar a base de dados
#
# 2- Eliminar as colunas de dados qualitativos
#
# 3- Excluir as linhas com respostas nulas
#
# 4- Renomear colunas
#
# 5- Transformar as respostas em números (importante ter acesso ao forms que gerou o dataframe para isso)
#
# 6- Exportar o data_frame

# %%
import pandas as pd

# %%
#Importando a Base de Dados (ela desve estar no mesmo local do seu arquivo jupyter)
respostas_mono_df = pd.read_csv(r'Formulário para Casais (Monografia) (respostas).csv', sep =',', encoding ='utf-8', on_bad_lines = 'skip')
display(respostas_mono_df)
respostas_mono_df.info()
# Out:
#     Carimbo de data/hora Qual sua faixa etária?         Escolaridade  \
# 0    10/03/2023 13:24:03                     NaN                 NaN
# 1    15/03/2023 18:50:58            36 á 41 anos  Graduação em curso
# 2    15/03/2023 21:50:25        Acima de 42 anos       Pós Graduação
# 3    05/04/2023 09:29:12            36 á 41 anos       Pós Graduação
# 4    05/04/2023 09:29:33        Acima de 42 anos       Pós Graduação
# ..                   ...                     ...                 ...
# 377  06/04/2023 08:45:41        Acima de 42 anos  Graduação completa
# 378  06/04/2023 08:47:10        Acima de 42 anos       Pós Graduação
# 379  06/04/2023 08:49:56        Acima de 42 anos        Ensino Médio
# 380  06/04/2023 08:56:58            24 á 29 anos  Graduação completa
# 381  06/04/2023 08:58:26            24 á 29 anos       Pós Graduação
#
#     Qual seu gênero? Qual sua religião? Local do Brasil onde mora  \
# 0                NaN                NaN                       NaN
# ...

# %%
#As colunas 'Carimbo de data/hora' e 'Se você respondeu sim, para a ultima pergunta, quais expectativas foram quebradas?' e
#'Conte um pouco de como foi o início do casamento para voce?' são abertas e por isso serão excluídas da análise
respostas_mono_df = respostas_mono_df.drop(['Carimbo de data/hora','Se você respondeu sim, para a ultima pergunta, quais expectativas foram quebradas? ','Conte um pouco de como foi o início do casamento para voce? '], axis = 1)

# %%
#Além da primeira linha, que só tem elementos nulos queremos excluir todas as linhas que tenhas respostas nulas
respostas_mono_df = respostas_mono_df.dropna(subset = ['Qual sua faixa etária? ','Local do Brasil onde mora','Escolaridade', 'Qual seu gênero?','Qual sua religião?','Estado cívil','Quantos anos você tinha quando se casou?','Raça','Você namorou por quanto tempo antes de se casar?','Quanto tempo de noivado/preparação para o casamento?','Pelo dicionário expectativas podem ser compreendidas como, situação de quem espera a ocorrência de algo, ou sua probabilidade de ocorrência, em determinado momento. Na sua perspectiva, as expectativas: ','Quais eram ás suas expectativas no inicio do casamento?','As expectativas citadas na questão acima, se supriram ao longo do tempo? ','Quais fatores eram importantes para sustentar as expectativas criadas para o matrimônio? (Você pode marcar mais de uma).','Na sua perspectiva, quais eram as expectativas que seu conjuge tinha em relação ao casamento no ínicio? ','Quais sentimentos apareceram nos primeiros anos de casado? (Tendo como referência os primeiros dois anos)', 'Por algum momento você se arrependeu de ter casado?','Algum dos motivos para você ter se arrependido de se casar foi devido a uma quebra de expectativas?', 'O que você fez quando houve quebra de expectativas? ','E atualmente, depois de um tempo de casado, quais caracteristicas são mais importantes para sustentar as expectativas criadas para o matrimônio? (Você pode marcar mais de uma).','E hoje, você se permite criar expectativas para o casamento? ','Se a sua resposta foi sim, na pergunta anterior, depois de um tempo de casado, quais são as expectativas para os proximos anos? ','O que foi importante para moldar e criar suas expectativas em relação ao casamento?'])
#Faremos o reset_index() para reorganizar o dataframe
respostas_mono_df = respostas_mono_df.reset_index()
display(respostas_mono_df)
# Out:
#      index Qual sua faixa etária?         Escolaridade Qual seu gênero?  \
# 0        4        Acima de 42 anos       Pós Graduação           Femino
# 1        9            24 á 29 anos  Graduação em curso           Femino
# 2       11            30 á 35 anos       Pós Graduação           Femino
# 3       14            24 á 29 anos        Ensino Médio           Femino
# 4       15        Acima de 42 anos        Ensino Médio           Femino
# ..     ...                     ...                 ...              ...
# 166    371            30 á 35 anos       Pós Graduação           Femino
# 167    373            36 á 41 anos       Pós Graduação           Femino
# 168    375        Acima de 42 anos        Ensino Médio           Femino
# 169    376            30 á 35 anos  Graduação em curso           Femino
# 170    380            24 á 29 anos  Graduação completa           Femino
#
#                                     Qual sua religião?  \
# ...

# %%
#Renomear as colunas para melhor identificação e visualização dos dados
respostas_mono_df = respostas_mono_df.rename(columns={'Qual sua faixa etária? ':'Faixa etária'}) #nesse caso havia um espaço após a '?' 
respostas_mono_df = respostas_mono_df.rename(columns={'Qual seu gênero?':'Gênero'})
respostas_mono_df = respostas_mono_df.rename(columns={'Qual sua religião?':'Religião'})
respostas_mono_df = respostas_mono_df.rename(columns={'Local do Brasil onde mora':'Região'})
respostas_mono_df = respostas_mono_df.rename(columns={'Quantos anos você tinha quando se casou?': 'Idade de casamento'})
respostas_mono_df = respostas_mono_df.rename(columns={'Você namorou por quanto tempo antes de se casar?':'Tempo de namoro'})
respostas_mono_df = respostas_mono_df.rename(columns={'Quanto tempo de noivado/preparação para o casamento?':'Tempo de noivado'})
respostas_mono_df = respostas_mono_df.rename(columns={'Pelo dicionário expectativas podem ser compreendidas como, situação de quem espera a ocorrência de algo, ou sua probabilidade de ocorrência, em determinado momento. Na sua perspectiva, as expectativas: ':'Importância Expectativas'})
respostas_mono_df = respostas_mono_df.rename(columns={'Quais eram ás suas expectativas no inicio do casamento?':'Expectativas Iniciais'})
respostas_mono_df = respostas_mono_df.rename(columns={'As expectativas citadas na questão acima, se supriram ao longo do tempo? ':'Expectativas Supridas'})
respostas_mono_df = respostas_mono_df.rename(columns={'Quais fatores eram importantes para sustentar as expectativas criadas para o matrimônio? (Você pode marcar mais de uma).':'Fatores'})
respostas_mono_df = respostas_mono_df.rename(columns={'Na sua perspectiva, quais eram as expectativas que seu conjuge tinha em relação ao casamento no ínicio? ':'Expectativas Conjuge'})
respostas_mono_df = respostas_mono_df.rename(columns={'Quais sentimentos apareceram nos primeiros anos de casado? (Tendo como referência os primeiros dois anos)':'Sentimentos'})
respostas_mono_df = respostas_mono_df.rename(columns={'Por algum momento você se arrependeu de ter casado?':'Arrependimento'})
respostas_mono_df = respostas_mono_df.rename(columns={'Algum dos motivos para você ter se arrependido de se casar foi devido a uma quebra de expectativas?':'Quebra de Expectativas'})
respostas_mono_df = respostas_mono_df.rename(columns={'O que você fez quando houve quebra de expectativas? ':'Reação'})
respostas_mono_df = respostas_mono_df.rename(columns={'E atualmente, depois de um tempo de casado, quais caracteristicas são mais importantes para sustentar as expectativas criadas para o matrimônio? (Você pode marcar mais de uma).':'Fatores Atualmente'})
respostas_mono_df = respostas_mono_df.rename(columns={'E hoje, você se permite criar expectativas para o casamento? ':'Expectativas hoje'})
respostas_mono_df = respostas_mono_df.rename(columns={'Se a sua resposta foi sim, na pergunta anterior, depois de um tempo de casado, quais são as expectativas para os proximos anos? ':'Expectativas próximos anos'})
respostas_mono_df = respostas_mono_df.rename(columns={'O que foi importante para moldar e criar suas expectativas em relação ao casamento?':'Referências'})

#Coloquei cada coluna em uma linha separada para melhor visualização mas todas poderiam estar no mesmo dicionário.

# %%
#Para fins estatísticos atribuirei a cada resposta fechada um valor numérico. Quando esta resposta estiver numa escala ou
#multipla escolha os valores irão de 1 até o número de alternativas, para perguntas de sim ou não atribui 0 pra não e 1 pra sim.
#Usarei uma iteração com for para garantir que o valor atribuido seja computado como um inteiro
lista = []
for i in respostas_mono_df['Faixa etária']: #i será a info de cada linha de respostas na coluna selecionada
    if '18 a 23 anos' in i: #Aqui vamos determinar qual a informação contida em i
        lista.append(1) #Se a informação for essa atribuiremos o valor 1, se não, segue.
    elif '24 á 29 anos' in i:
        lista.append(2)
    elif '30 á 35 anos' in i:
        lista.append(3)
    elif '36 á 41 anos' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Faixa etária'] = lista #Aqui substituimos a coluna antiga pela lista de valores numéricor gerada
respostas_mono_df[['Faixa etária']] #conferimos se realmente funcionou imprimindo a coluna
# Out:
#      Faixa etária
# 0               5
# 1               2
# 2               3
# 3               2
# 4               5
# ..            ...
# 166             3
# 167             4
# 168             5
# 169             3
# 170             2
#
# [171 rows x 1 columns]

# %%
lista = []
for i in respostas_mono_df['Escolaridade']: 
    if 'Ensino Fundamental' in i: 
        lista.append(1)
    elif 'Ensino Médio' in i:
        lista.append(2)
    elif 'Graduação em curso' in i:
        lista.append(3)
    elif 'Graduação em curso' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Escolaridade'] = lista
respostas_mono_df[['Escolaridade']]

lista = []
for i in respostas_mono_df['Gênero']: 
    if 'Masculino' in i: 
        lista.append(1)
    elif 'Femino' in i: #Aqui o termo 'feminino' possuia um erro de digitação, ficou como 'femino'
        lista.append(2)
    else:
        lista.append(3)
respostas_mono_df['Gênero'] = lista
respostas_mono_df[['Gênero']]

lista = []
for i in respostas_mono_df['Religião']: #Por causa dos resultados da pesquisa vamos contar todos não evangelicos e catolicos juntos
    if 'Evangelico' in i: 
        lista.append(1)
    elif 'Católico' in i:
        lista.append(2)
    else:
        lista.append(3)
respostas_mono_df['Religião'] = lista
respostas_mono_df[['Religião']]

lista = []
for i in respostas_mono_df['Região']: 
    if 'Sudeste' in i: 
        lista.append(1)
    elif 'Nordeste' in i:
        lista.append(2)
    elif 'Sul' in i:
        lista.append(3)
    elif 'Centro Oeste' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Região'] = lista
respostas_mono_df[['Região']]

lista = []
for i in respostas_mono_df['Estado cívil']: 
    if 'Casado' in i :
        lista.append(1)
    elif 'União estável (casado apenas no cartório)' in i:
        lista.append(2)
    elif 'Amigado (moram juntos, mas não tiveram registro no cartório e religioso)' in i:
        lista.append(3)
    elif 'Casado apenas no religioso' in i:
        lista.append(4)
    elif 'Casados mas moram em residências diferentes' in i:
        lista.append(5)
    else:
        lista.append(6)
respostas_mono_df['Estado cívil'] = lista
respostas_mono_df[['Estado cívil']]

lista = []
for i in respostas_mono_df['Raça']: 
    if 'Branco' in i :
        lista.append(1)
    elif 'Negro' in i:
        lista.append(2)
    elif 'Pardo' in i:
        lista.append(3)
    else:
        lista.append(4)
respostas_mono_df['Raça'] = lista
respostas_mono_df[['Raça']]

lista = []
for i in respostas_mono_df['Idade de casamento']: 
    if '18 a 23 anos' in i :
        lista.append(1)
    elif '24 a 29 anos' in i:
        lista.append(2)
    elif '30 a 35 anos' in i:
        lista.append(3)
    elif '36 a 41 anos' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Idade de casamento'] = lista
respostas_mono_df[['Idade de casamento']]

lista = []
for i in respostas_mono_df['Tempo de namoro']: 
    if 'Menos de 1 ano' in i :
        lista.append(1)
    elif 'Entre 1 e 2 anos' in i:
        lista.append(2)
    elif 'Entre 2 e 3 anos' in i:
        lista.append(3)
    elif 'Entre 3 e 4 anos' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Tempo de namoro'] = lista
respostas_mono_df[['Tempo de namoro']]

lista = []
for i in respostas_mono_df['Tempo de noivado']: 
    if 'menos de 6 meses' in i :
        lista.append(1)
    elif 'Entre 6 e 1 ano' in i:
        lista.append(2)
    elif '1 e 2 anos' in i:
        lista.append(3)
    elif '2 e 3 anos' in i:
        lista.append(4)
    else:
        lista.append(5)
respostas_mono_df['Tempo de noivado'] = lista
respostas_mono_df[['Tempo de noivado']]

lista = []
for i in respostas_mono_df['Importância Expectativas']: 
    if 'São importantes para saúde e manutenção do casamento' in i :
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Importância Expectativas'] = lista
respostas_mono_df[['Importância Expectativas']]

lista = []
for i in respostas_mono_df['Expectativas Supridas']: 
    if 'sim' in i :
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expectativas Supridas'] = lista
respostas_mono_df[['Expectativas Supridas']]

lista = []
for i in respostas_mono_df['Arrependimento']: 
    if 'sim' in i :
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Arrependimento'] = lista
respostas_mono_df[['Arrependimento']]

lista = []
for i in respostas_mono_df['Expectativas hoje']: 
    if 'Sim' in i :
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expectativas hoje'] = lista
respostas_mono_df[['Expectativas hoje']]
# Out:
#      Expectativas hoje
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ..                 ...
# 166                  1
# 167                  1
# 168                  1
# 169                  1
# 170                  1
#
# [171 rows x 1 columns]

# %%
lista=[]
for i in respostas_mono_df['Quebra de Expectativas']:
    if 'sim' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Quebra de Expectativas'] = lista

# %%
#As perguntas com mais de uma resposta exigem um tratamento específico. Nesses casos vamos criar uma coluna nova para cada
#alternativa com 0 se não tiver sido marcada e 1 caso tenha sido marcada.

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Reciprocidade Amorosa' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Reciprocidade']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Aceitação Social' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Aceitação Social']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Ascensão financeira' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Ascensão financeira']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Segurança afetiva (vínculo seguro e constante)' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Segurança Afetiva']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Ter filhos' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Ter filhos']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Cerimônia e festa de casamento (exemplo: se vestir de noiva(o))' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Cerimônia e Festa']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Condições de sair da casa dos meus pais e construir minha própria família' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Independencia']=lista

lista =[]
for i in respostas_mono_df['Expectativas Iniciais']:
    if 'Não me lembro' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Inic. Não me lembro']=lista

# %%
lista = []
for i in respostas_mono_df['Fatores']:
    if 'Personalidade do meu conjuge' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Personalidade'] = lista

lista = []
for i in respostas_mono_df['Fatores']:
    if 'Financeiros' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Financeiro'] = lista

lista = []
for i in respostas_mono_df['Fatores']:
    if 'A família do conjuge' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Família Conjuge'] = lista

lista = []
for i in respostas_mono_df['Fatores']:
    if 'Ambiente (aspectos referentes a casa, como ter uma casa propria ou ter uma casa bonita)' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Ambiente']=lista

lista = []
for i in respostas_mono_df['Fatores']:
    if 'Minha família' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Minha Família']=lista

lista = []
for i in respostas_mono_df['Fatores']:
    if 'Trabalho (jornada, turno, tempo de descanso, etc)' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores - Trabalho']=lista

# %%
lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Reciprocidade Amorosa' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Reciprocidade']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Aceitação Social' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Aceitação Social']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Ascensão financeira' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Ascensão financeira']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Segurança afetiva (vínculo seguro e constante)' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Segurança Afetiva']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Ter filhos' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Ter filhos']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Cerimônia e festa de casamento (exemplo: se vestir de noiva(o))' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Cerimônia e Festa']=lista

lista =[]
for i in respostas_mono_df['Expectativas Conjuge']:
    if 'Condições de sair da casa dos meus pais e construir minha própria família' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Exp.Conj. Independencia']=lista

# %%
lista=[]
for i in respostas_mono_df['Fatores Atualmente']:
    if 'Personalidade do meu conjuge' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores Atual - Personalidade']=lista

lista=[]
for i in respostas_mono_df['Fatores Atualmente']:
    if 'Financeiros' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores Atual - Financeiro']=lista

lista=[]
for i in respostas_mono_df['Fatores Atualmente']:
    if 'A família do conjuge ou minha familia' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores Atual - Família']=lista

lista=[]
for i in respostas_mono_df['Fatores Atualmente']:
    if 'Ambiente' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Fatores Atualmente - Ambiente']=lista

# %%
lista= []
for i in respostas_mono_df['Reação']:
    if 'Convesei' in i: #Aqui tem um erro de digitação
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Conversei']=lista

lista= []
for i in respostas_mono_df['Reação']:
    if 'Procurei Terapia individual' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Terapia']=lista

lista= []
for i in respostas_mono_df['Reação']:
    if 'Pedi ajuda de lideres religiosos' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Ajuda Religiosa']=lista

lista= []
for i in respostas_mono_df['Reação']:
    if 'Foquei mais no trabalho' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Trabalhar']=lista

lista= []
for i in respostas_mono_df['Reação']:
    if 'Me separei' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Separação']=lista

lista= []
for i in respostas_mono_df['Reação']:
    if 'Perseverei e tentei reajustar a relação' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Reação - Perseverar']=lista

# %%
lista=[]
for i in respostas_mono_df['Sentimentos']:
    if 'Alegria' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Sent - Alegria']=lista

lista=[]
for i in respostas_mono_df['Sentimentos']:
    if 'Tristeza' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Sent - Tristeza']=lista

lista=[]
for i in respostas_mono_df['Sentimentos']:
    if 'Arrependimento' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Sent - Arrependimento']=lista

lista=[]
for i in respostas_mono_df['Sentimentos']:
    if 'Medo' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Sent - Medo']=lista

# %%
lista=[]
for i in respostas_mono_df['Expectativas próximos anos']:
    if 'Personalidade do meu conjuge' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expec. Prox. - Personalidade']=lista

lista=[]
for i in respostas_mono_df['Expectativas próximos anos']:
    if 'Financeiros' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expec. Prox. - Financeiros']=lista

lista=[]
for i in respostas_mono_df['Expectativas próximos anos']:
    if 'A família do conjuge ou minha familia' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expec. Prox. - Família']=lista

lista=[]
for i in respostas_mono_df['Expectativas próximos anos']:
    if 'Ambiente' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Expec. Prox. - Ambiente']=lista

# %%
lista=[]
for i in respostas_mono_df['Referências']:
    if 'Filmes' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Referência - Filmes']=lista

lista=[]
for i in respostas_mono_df['Referências']:
    if 'Histórias antigas das minhas referências (pais, avós, familiares, líderes)' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Referência - Histórias']=lista

lista=[]
for i in respostas_mono_df['Referências']:
    if 'Valores' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Referência - Valores']=lista

lista=[]
for i in respostas_mono_df['Referências']:
    if 'Religião' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Referência - Religião']=lista

lista=[]
for i in respostas_mono_df['Referências']:
    if 'Trabalho do meu conjuge' in i:
        lista.append(1)
    else:
        lista.append(0)
respostas_mono_df['Referência - Trabalho']=lista

# %%
#Aqui exclui todas as colunas de respostas de multipla escolha que destrinchamos em tabelas de frequência para cada reposta
respostas_mono_df = respostas_mono_df.drop(['index','Expectativas Iniciais', 'Fatores','Expectativas Conjuge','Sentimentos','Reação','Fatores Atualmente','Expectativas próximos anos','Referências'], axis =1)

# %%
respostas_mono_df.info()
display(respostas_mono_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Faixa etária                   171 non-null    int64
#  1   Escolaridade                   171 non-null    int64
#  2   Gênero                         171 non-null    int64
#  3   Religião                       171 non-null    int64
#  4   Região                         171 non-null    int64
#  5   Estado cívil                   171 non-null    int64
#  6   Raça                           171 non-null    int64
#  7   Idade de casamento             171 non-null    int64
#  8   Tempo de namoro                171 non-null    int64
#  9   Tempo de noivado               171 non-null    int64
#  10  Importância Expectativas       171 non-null    int64
#  11  Expectativas Supridas          171 non-null    int64
# ...

# %%
#Agora exportaremos o nosso Data Frame em CSV para que sejam analisados os dados estatísticos em um programa a parte
respostas_mono_df.to_csv(r'Respostas Pesquisa Monografia.csv', sep=';', encoding='utf-8')
